# %%
gv=20
def read_gv():
    print(gv)
def write_gv():
    global gv
    gv=2
def write1_gv():
    gv=3000  #does not overwrite the existing global variable value
read_gv()
write_gv()
read_gv()
write1_gv()
read_gv()

# %%
a=[1,2,3,4,5]
print(4 in a)
print(4 not in a)

# %%
b=lambda x:x*5
c=20*[0]
for i in range(1,21):
    c[i-1]=b(i)
print(c)

# %%
# yield
def generator():
    for i in range(20):
        yield i*i
        


g = generator()
for n in g:
    print(n)

# %%
j=21
sq={x:x*x for x in range (j)}
print (sq)
x=j*[0]
for i in sq:
    x[i]=sq[i]
print(x)

# %%
tasks=[None]*264


def test():
    while True:
        
        
                
        print('Options')
        print('='*8)
        print('Press 1 to add task ')
        print('Press 2 to exit ')
        print('Press 3 to view tasks ')
        option=input("Enter a option . ")
        if option =='1':
            for i,task in enumerate(tasks,1):
                n=i-1
                if tasks[n] is None:            
                    task=input("Enter a task or Press 'b' to go back to options. ")
                    global o
                    o=i
                    
                    if task=='b':
                        break                                                
                    tasks[n]=task
                    print(f"{i}.{tasks[n]}")                
                if i>=len(tasks):
                    break                
        elif option =='2':
            g=print('bye')
            break
        elif option=='3':
            if tasks[0] is None:
                print('No tasks')
            else:
                print("Tasks")
                print('-'*6)
                o=o-1
                for i in range (o):
                    print(f"{i+1}.{tasks[i]}")
                                                
test()            
file="random.txt"

def test2():
    if not os.path.exists(file):
        return[]

    with open(file,'r')as f:
        taskss=[line.strip() for line in f if line.strip()]
    return taskss
# Out:
# Options
# ...
# Press 1 to add task
# Press 2 to exit
# Press 3 to view tasks
# 1.fkjfksf
# 2.3
# Options
# ...
# Press 1 to add task
# Press 2 to exit
# Press 3 to view tasks
# Tasks
# ------
# 1.fkjfksf
# 2.3
# Options
# ...
# Press 1 to add task
# Press 2 to exit
# Press 3 to view tasks
# bye
